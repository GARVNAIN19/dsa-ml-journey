# %% [markdown]
# <a href="https://colab.research.google.com/github/GARVNAIN19/dsa-ml-journey/blob/main/ml/day05_cross_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df = df.drop(['Cabin', 'Name', 'Ticket', 'PassengerId'], axis=1)
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

y = df['Survived']
X = df.drop('Survived', axis=1)

print("Ready! ✅")
# Out:
# Ready! ✅

# %%
# Cross validate Random Forest with 5 folds
model = RandomForestClassifier(n_estimators=100, random_state=42)

scores = cross_val_score(model, X, y, cv=5)

print("Scores for each fold:")
for i, score in enumerate(scores):
    print(f"Fold {i+1}: {score*100:.2f}%")

print(f"\nAverage accuracy: {scores.mean()*100:.2f}%")
print(f"Standard deviation: {scores.std()*100:.2f}%")
# Out:
# Scores for each fold:
# Fold 1: 78.77%
# Fold 2: 80.34%
# Fold 3: 85.39%
# Fold 4: 77.53%
# Fold 5: 84.27%
#
# Average accuracy: 81.26%
# Standard deviation: 3.07%

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

print("Model Comparison with Cross Validation:")
print("=" * 45)
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5)
    print(f"{name}: {scores.mean()*100:.2f}% (+/- {scores.std()*100:.2f}%)")
# Out:
# Model Comparison with Cross Validation:
# ...
# Logistic Regression: 79.35% (+/- 1.82%)
# Decision Tree: 77.67% (+/- 3.64%)
# Random Forest: 81.26% (+/- 3.07%)

# %%
print("=" * 45)
print("FINAL ML JOURNEY SUMMARY")
print("=" * 45)
print("\nDataset: Titanic (891 passengers)")
print("Task: Predict survival (0 or 1)")
print("\nBest Model: Random Forest")
print("Cross Val Accuracy: 81.26%")
print("Single Test Accuracy: 82.12%")
print("\nKey Findings:")
print("1. Gender was most important feature")
print("2. Ticket class was second most important")
print("3. Random Forest beats simpler models")
print("4. Cross validation gives more reliable scores")
# Out:
# ...
# FINAL ML JOURNEY SUMMARY
# ...
#
# Dataset: Titanic (891 passengers)
# Task: Predict survival (0 or 1)
#
# Best Model: Random Forest
# Cross Val Accuracy: 81.26%
# Single Test Accuracy: 82.12%
#
# Key Findings:
# 1. Gender was most important feature
# 2. Ticket class was second most important
# 3. Random Forest beats simpler models
# 4. Cross validation gives more reliable scores
